# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/107.7 GB disk)

# %%
# !unzip /content/Helmets_Dataset.zip -d ../
# Out:
# Archive:  /content/Helmets_Dataset.zip
#    creating: ../Helmets_Dataset/images/
#    creating: ../Helmets_Dataset/images/train/
#   inflating: ../Helmets_Dataset/images/train/BikesHelmets0_png.rf.fd4ec6513a3e1a5bbd29105b435e00a7.jpg
#   inflating: ../Helmets_Dataset/images/train/BikesHelmets100_png.rf.faba1f6b650de1227c175f81b1225802.jpg
#   inflating: ../Helmets_Dataset/images/train/BikesHelmets101_png.rf.fa832e691c4db62925764b14dd01ffb7.jpg
#   inflating: ../Helmets_Dataset/images/train/BikesHelmets102_png.rf.fa20302e0bb6e593293177d3e611c0a8.jpg
#   inflating: ../Helmets_Dataset/images/train/BikesHelmets103_png.rf.1bdc01452093944798a21f2fa46be72a.jpg
#   inflating: ../Helmets_Dataset/images/train/BikesHelmets106_png.rf.162bd70150768434ae0782876acafdf0.jpg
#   inflating: ../Helmets_Dataset/images/train/BikesHelmets107_png.rf.620b691501dae2487bd53d334f520d15.jpg
#   inflating: ../Helmets_Dataset/images/train/BikesHelmets108_png.rf.6732cfd85a929f102fbf5a7db58d499e.jpg
# ...

# %% [markdown]
# # 1. Detect
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           screen  # screenshot
#                           path/  # directory
#                           'path/*.jpg'  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights /content/best.pt --img 640 --hide-conf --source /content/Bike-1569585528.jpg
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['/content/best.pt'], source=/content/Bike-1569585528.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=True, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/Bike-1569585528.jpg: 416x640 1 Triple Riding, 233.2ms
# Speed: 2.7ms pre-process, 233.2ms inference, 21.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-175-g1460e57 Python-3.7.14 torch-1.12.1+cu113 CPU
#
# ...

# %% [markdown]
# #### The code starts training and logs the progress, including model architecture, layer information, and performance metrics. The training process includes data augmentation techniques and caching mechanisms to optimize performance. If an error occurs, it typically involves debugging the data loading or model configuration.
